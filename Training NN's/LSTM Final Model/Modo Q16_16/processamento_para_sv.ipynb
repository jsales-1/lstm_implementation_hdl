# %%
a= 1

# %%
def float_to_q16_16(value):
    """Converte float para Q16.16 (formato signed 32 bits)"""
    scaled = value * 65536
    rounded = int(round(scaled))
    
    # Satura para 32 bits signed
    if rounded > 2**31 - 1:
        rounded = 2**31 - 1
    elif rounded < -2**31:
        rounded = -2**31
    
    return rounded


def gerar_x_array(valores):
    """
    Gera código para inicializar array x a partir de valores float.
    
    Args:
        valores: Lista de floats
    
    Returns:
        String com as atribuições formatadas
    """
    q16_values = [float_to_q16_16(v) for v in valores]
    
    linhas = []
    linha_atual = ""
    
    for i, qval in enumerate(q16_values):
        if qval >= 0:
            atrib = f"x[{i}] =  32'sd{qval};"
        else:
            atrib = f"x[{i}] = -32'sd{abs(qval)};"
        
        linha_atual += f"{atrib}  "
        
        if (i + 1) % 8 == 0 or i == len(valores) - 1:
            linhas.append(linha_atual.strip())
            linha_atual = ""
    
    return "\n".join(linhas)

# %%
valores = [ 0.00646 ,  0.044838, -0.006987,  0.013634,  0.138786,  0.003727,
   0.156973,  0.04163 , -0.096376,  0.088423,  0.087307, -0.119151,
  -0.002892, -0.119615,  0.08102 ,  0.040254,  0.133419,  0.118099,
   0.050178, -0.065761,  0.063758, -0.060514, -0.024374,  0.022444,
   0.066803, -0.06559 , -0.138173, -0.064624, -0.079424, -0.192176,
   0.130207, -0.151234, -0.008673, -0.028815, -0.061212,  0.012162,
   0.063069,  0.082551, -0.135395,  0.052267,  0.01952 , -0.10368 ,
   0.11501 , -0.055135, -0.12211 , -0.115265,  0.059448,  0.074828,
   0.05106 ,  0.049603, -0.035402, -0.016037,  0.018755,  0.006926,
  -0.147672,  0.042092, -0.001473,  0.075605,  0.116384,  0.154746,
   0.136101,  0.02067 ,  0.07456 , -0.119501]


print(gerar_x_array(valores))
# Out:
# x[0] =  32'sd423;  x[1] =  32'sd2939;  x[2] = -32'sd458;  x[3] =  32'sd894;  x[4] =  32'sd9095;  x[5] =  32'sd244;  x[6] =  32'sd10287;  x[7] =  32'sd2728;
# x[8] = -32'sd6316;  x[9] =  32'sd5795;  x[10] =  32'sd5722;  x[11] = -32'sd7809;  x[12] = -32'sd190;  x[13] = -32'sd7839;  x[14] =  32'sd5310;  x[15] =  32'sd2638;
# x[16] =  32'sd8744;  x[17] =  32'sd7740;  x[18] =  32'sd3288;  x[19] = -32'sd4310;  x[20] =  32'sd4178;  x[21] = -32'sd3966;  x[22] = -32'sd1597;  x[23] =  32'sd1471;
# x[24] =  32'sd4378;  x[25] = -32'sd4299;  x[26] = -32'sd9055;  x[27] = -32'sd4235;  x[28] = -32'sd5205;  x[29] = -32'sd12594;  x[30] =  32'sd8533;  x[31] = -32'sd9911;
# x[32] = -32'sd568;  x[33] = -32'sd1888;  x[34] = -32'sd4012;  x[35] =  32'sd797;  x[36] =  32'sd4133;  x[37] =  32'sd5410;  x[38] = -32'sd8873;  x[39] =  32'sd3425;
# x[40] =  32'sd1279;  x[41] = -32'sd6795;  x[42] =  32'sd7537;  x[43] = -32'sd3613;  x[44] = -32'sd8003;  x[45] = -32'sd7554;  x[46] =  32'sd3896;  x[47] =  32'sd4904;
# ...

# %%
def float_to_q16_16(value):
    """Converte float para Q16.16 (formato signed 32 bits)"""
    scaled = value * 65536
    rounded = int(round(scaled))

    if rounded > 2**31 - 1:
        rounded = 2**31 - 1
    elif rounded < -2**31:
        rounded = -2**31

    return rounded


def gerar_x_array_2d(valores):
    """
    Gera código:
    x[i][j] = ±32'sdN;

    Aceita:
        shape (N,M)
        ou (1,N,M)
    """

    # remove dimensão batch se existir
    if len(valores) == 1 and isinstance(valores[0][0], list):
        valores = valores[0]

    linhas = []

    for i, linha in enumerate(valores):

        linha_atual = ""

        for j, valor in enumerate(linha):

            qval = float_to_q16_16(valor)

            if qval >= 0:
                atrib = f"x[{i}][{j}] =  32'sd{qval};"
            else:
                atrib = f"x[{i}][{j}] = -32'sd{abs(qval)};"

            linha_atual += f"{atrib}   "

        linhas.append(linha_atual.rstrip())

    return "\n".join(linhas)

# %%
matriz = [[[-7.866774e-03, -2.221364e-03,  8.825177e-04, -1.552897e-03],
  [-7.866774e-03, -2.221364e-03,  8.825177e-04, -1.552897e-03],
  [-7.866774e-03, -2.221364e-03,  8.825177e-04, -1.552897e-03],
  [-7.866774e-03, -2.221364e-03,  8.825177e-04, -1.552897e-03],
  [-7.866774e-03, -2.221364e-03,  8.825177e-04, -1.552897e-03],
  [-7.866774e-03, -2.221364e-03,  8.825177e-04, -1.552897e-03],
  [-7.866774e-03, -2.221364e-03,  8.825177e-04, -1.552897e-03],
  [-7.866774e-03, -2.221364e-03,  8.825177e-04, -1.552897e-03],
  [-7.866774e-03, -2.221364e-03,  8.825177e-04, -1.552897e-03],
  [-7.866774e-03, -2.221364e-03,  8.825177e-04, -1.552897e-03],
  [-7.866774e-03, -2.221364e-03,  8.825177e-04, -1.552897e-03],
  [ 1.192876e-02,  3.851814e-02,  3.423961e-02, -4.644443e-02],
  [-2.996647e-03,  4.977713e-02, -2.036935e-02,  8.232650e-03],
  [ 2.394288e-02, -4.337658e-03,  1.344545e-02, -1.748542e-02],
  [-7.027274e-02,  4.802333e-02,  4.398237e-03, -8.957741e-02],
  [ 1.490701e-02, -5.952218e-02, -2.081794e-02,  2.889149e-02],
  [-9.640607e-03, -1.555191e-02, -2.791321e-02,  1.630008e-02],
  [ 2.445807e-03, -2.587288e-02, -1.432373e-02, -1.655451e-02],
  [-1.235699e-02,  5.310560e-05,  1.357727e-02, -1.390317e-02],
  [-6.821429e-02,  6.710445e-02,  4.376633e-02, -2.533838e-03],
  [ 7.955431e-03,  6.194082e-03,  3.153049e-03, -1.441632e-02],
  [ 9.323115e-03, -3.194746e-04,  1.899867e-02,  4.242232e-02],
  [ 2.017073e-02, -5.487790e-03, -7.902807e-03,  3.470867e-03],
  [ 7.815340e-03,  3.163922e-02, -5.537857e-02, -6.544302e-03],
  [ 6.872686e-02, -8.277700e-03,  3.497011e-02,  4.987487e-03],
  [ 7.636762e-03, -9.409743e-03,  6.200617e-02, -3.358069e-02],
  [ 5.277627e-02, -2.840040e-02, -3.879728e-03, -4.276105e-02],
  [-5.407651e-02, -5.626216e-03,  3.566168e-02, -6.017534e-02],
  [-1.083112e-01,  1.302247e-01,  4.622456e-02, -1.286028e-01],
  [-1.784590e-02, -1.935592e-02, -3.989368e-02,  5.849440e-03],
  [-4.699936e-02,  3.479239e-02,  3.326812e-02, -8.347293e-02],
  [ 7.636762e-03, -9.409743e-03,  6.200617e-02, -3.358069e-02],
  [-9.287739e-02,  5.437008e-02,  7.940652e-02,  2.944020e-03],
  [-1.492964e-02, -4.442601e-03,  8.452289e-03, -1.776678e-02],
  [-3.598984e-02,  2.494654e-02, -2.968751e-02,  1.102489e-02],
  [ 8.899180e-02, -5.303189e-02, -7.042697e-02,  2.342487e-02],
  [-5.307887e-02,  3.041684e-02,  6.119488e-02, -6.637975e-03],
  [ 7.340465e-03,  4.548908e-02,  4.202228e-03, -1.252587e-02],
  [-1.108715e-02,  1.217543e-02,  3.117213e-02,  7.995170e-03],
  [-1.009911e-02, -3.472379e-02, -3.013172e-02,  3.392728e-03],
  [ 9.206290e-02,  1.838961e-02, -2.389599e-02,  7.955460e-02],
  [-4.620409e-03, -4.083149e-03,  1.773780e-04,  7.036343e-04],
  [ 7.195578e-02, -3.139715e-02, -2.879969e-02,  7.425470e-02],
  [ 2.536331e-02, -5.231617e-02, -2.888113e-02,  4.954922e-02],
  [-2.151558e-02,  1.246239e-02,  1.411986e-02, -3.954583e-02],
  [-6.821429e-02,  6.710445e-02,  4.376633e-02, -2.533838e-03],
  [ 4.251913e-02, -4.798718e-03,  2.673700e-02, -1.850004e-02],
  [ 1.978279e-02, -3.203126e-02, -9.755444e-03,  3.502035e-02],
  [ 2.457583e-02,  1.522853e-02, -5.012801e-03,  1.167702e-02],
  [ 1.412207e-02, -2.695534e-02,  4.662873e-03, -2.460686e-02],
  [-4.844551e-02,  1.502326e-02,  7.678975e-02, -4.338812e-02],
  [ 7.761908e-03, -1.814506e-02,  8.452998e-03, -2.237555e-02],
  [-1.781000e-02,  5.106422e-03,  1.647116e-02, -8.332565e-03],
  [ 2.987020e-02,  1.214454e-03, -2.993861e-02,  2.205260e-02],
  [ 6.059582e-02,  7.411733e-03, -1.120343e-02, -3.707633e-02],
  [ 4.994237e-02, -4.675358e-03, -4.520814e-02,  3.120441e-02],
  [-9.039217e-03, -3.858096e-05,  4.903608e-02, -1.153522e-02],
  [ 7.364161e-02,  1.589034e-02, -1.964731e-02,  1.034659e-01],
  [ 3.025625e-03, -3.459245e-02, -4.174163e-02,  7.467348e-02],
  [-2.122954e-02,  4.602127e-02,  4.130530e-02, -5.882773e-02],
  [-4.759508e-02,  7.329229e-02,  2.607257e-02, -2.907011e-02],
  [ 7.011285e-02, -2.491928e-02, -5.303669e-02,  4.707185e-02],
  [ 1.423087e-02, -1.553450e-02, -2.161468e-02,  2.843978e-02],
  [ 2.879441e-02, -4.149597e-02,  3.364990e-03, -3.251293e-03],
  [-4.598968e-02,  1.151233e-02,  3.290834e-02,  6.620637e-03],
  [-2.222610e-02,  3.124739e-02,  6.220672e-02, -3.657574e-02],
  [ 4.888790e-03, -1.785638e-02,  1.207754e-02, -8.149367e-03],
  [ 8.948425e-02, -1.493479e-02,  2.671910e-02,  6.221497e-02],
  [ 4.194742e-02, -1.338089e-02, -5.331648e-02, -6.917247e-03],
  [ 3.595925e-02, -8.934397e-02,  1.234392e-02,  1.068241e-01],
  [-1.184956e-01,  3.367499e-02,  1.088129e-01, -6.160168e-02],
  [ 4.737910e-02, -4.215200e-02, -6.554418e-03,  2.594274e-02],
  [-1.184956e-01,  3.367499e-02,  1.088129e-01, -6.160168e-02]]]

# %%
print(gerar_x_array_2d(matriz))
# Out:
# x[0][0] = -32'sd516;   x[0][1] = -32'sd146;   x[0][2] =  32'sd58;   x[0][3] = -32'sd102;
# x[1][0] = -32'sd516;   x[1][1] = -32'sd146;   x[1][2] =  32'sd58;   x[1][3] = -32'sd102;
# x[2][0] = -32'sd516;   x[2][1] = -32'sd146;   x[2][2] =  32'sd58;   x[2][3] = -32'sd102;
# x[3][0] = -32'sd516;   x[3][1] = -32'sd146;   x[3][2] =  32'sd58;   x[3][3] = -32'sd102;
# x[4][0] = -32'sd516;   x[4][1] = -32'sd146;   x[4][2] =  32'sd58;   x[4][3] = -32'sd102;
# x[5][0] = -32'sd516;   x[5][1] = -32'sd146;   x[5][2] =  32'sd58;   x[5][3] = -32'sd102;
# x[6][0] = -32'sd516;   x[6][1] = -32'sd146;   x[6][2] =  32'sd58;   x[6][3] = -32'sd102;
# x[7][0] = -32'sd516;   x[7][1] = -32'sd146;   x[7][2] =  32'sd58;   x[7][3] = -32'sd102;
# x[8][0] = -32'sd516;   x[8][1] = -32'sd146;   x[8][2] =  32'sd58;   x[8][3] = -32'sd102;
# x[9][0] = -32'sd516;   x[9][1] = -32'sd146;   x[9][2] =  32'sd58;   x[9][3] = -32'sd102;
# ...
